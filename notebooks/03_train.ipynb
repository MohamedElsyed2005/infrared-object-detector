# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model.train(
    data="../data.yaml",
    epochs=50,
    imgsz=416,
    batch=2,
    name="ir_detector",
    project="runs",
    patience=10,
    augment=True
)
print("Training Done!")
print(f"Best weights: ../runs/ir_detector/weights/best.pt")
# Out:
# ...
# Ultralytics 8.4.45  Python-3.12.4 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...
