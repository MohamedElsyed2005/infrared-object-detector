# %%
from pathlib import Path
from ultralytics import YOLO

model_path = Path("runs/detect/runs/ir_detector/weights/best.pt")
model = YOLO(model_path)

metrics = model.val(
    data="../data.yaml",
    split='test'   # evaluate on test set specifically
)

print("=" * 40)
print(f"mAP50:     {metrics.box.map50:.3f}")
print(f"mAP50-95:  {metrics.box.map:.3f}")
print(f"Precision: {metrics.box.mp:.3f}")
print(f"Recall:    {metrics.box.mr:.3f}")
print("=" * 40)
# Out:
# Ultralytics 8.4.45  Python-3.12.4 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.30.1 ms, read: 6.11.3 MB/s, size: 39.0 KB)
# val: Scanning C:\Hamo\Courses\University\Semester 6\Visual Recognition\infrared-object-detector\data\test\labels... 108 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 108/108 448.5it/s 0.2s1s
# val: New cache created: C:\Hamo\Courses\University\Semester 6\Visual Recognition\infrared-object-detector\data\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.7it/s 1.5s0.2ss
#                    all        108        743      0.962      0.923      0.976      0.813
#                bicycle         99        183      0.957      0.831      0.956      0.729
#                    car         89        218      0.979      0.995      0.994      0.959
#                 people        107        342       0.95      0.943       0.98       0.75
# Speed: 1.1ms preprocess, 6.7ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to C:\Hamo\Courses\University\Semester 6\Visual Recognition\infrared-object-detector\notebooks\runs\detect\val
# ========================================
# mAP50:     0.976
# mAP50-95:  0.813
# Precision: 0.962
# Recall:    0.923
# ========================================
